# %%
import pandas as pd

all_reviews = pd.read_csv('review_data/all_reviews.csv')
all_reviews.head()
# Out:
#    split  review_id  year category language  \
# 0  train          0  2007   screen       nb
# 1  train          1  2007   screen       nb
# 2  train          2  2008   screen       nb
# 3  train          3  2008   screen       nb
# 4  train          4  2009   screen       nb
#
#                                       title  \
# 0                                  Rome S02
# 1  Twin Peaks - definitive gold box edition
# 2                     The Wire (sesong 1-4)
# 3                        Mad Men (sesong 1)
# 4                        Mad Men (sesong 2)
#
#                                              excerpt  rating
# 0                  Toppen innen tv-drama akkurat nå!       6
# 1                 Gull for <em>Twin Peaks</em>-fans!       6
# 2  The Wire vil gjøre deg avhengig, men på en god...       6
# 3              Stilig, underholdende og sofistikert!       5
# 4              TV-underholdning av høyeste kvalitet!       5

# %%
all_reviews['rating'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot: >

# %%
all_reviews['year'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot: >

# %%
all_reviews['category'].value_counts().plot.bar()
# Out:
# <AxesSubplot: >

# %%
all_reviews['language'].value_counts().plot.bar()
# Out:
# <AxesSubplot: >
